# %% [markdown]
# Test 1:
# No Observe code enables
#
# Test 2:
# Lua Code with no parameters (always returns false)
#
# Test 2b:
# Lua Code with no parameters (always returns true, followed by post processing of stats)
#
# Test 3a:
# Lua code with no parameters pushed, just create table for each function call (always returns true, followed by post processing of stats)
#
# Test 3b:
# Lua code with one parameter pushed (integer value pushed) (return true for 2% of requests)
#
# Test 3b2:
# Lua code with one parameter pushed (integer value pushed) (always returns true, followed by post processing of stats)
#
# Test 3c:
# Lua code with two parameters pushed (integer value pushed) (return true for 2% of requests)
#
# Test 3d:
# Lua code with three parameters pushed (integer value pushed) (return true for 2% of requests)
#
# Test 3e:
# Lua code with 1 integer parameter and 2 string parameters pushed to the stack (return true for 2% of requests)

# %%
import matplotlib.pyplot as plt

# Iteration numbers (assumed 10 runs)
iterations = list(range(1, 11))

throughput_set_conf1 =  [135226.50, 139918.84, 140765.77, 140429.72, 134952.77,
                         143802.12, 144341.80, 145815.11, 135888.03, 139860.14]
latency_set_conf1    =  [0.098, 0.094, 0.094, 0.094, 0.098,
                         0.092, 0.092, 0.091, 0.097, 0.094]

throughput_get_conf1 =  [143905.59, 145645.20, 144341.80, 139489.47, 145496.88,
                         148698.89, 145475.70, 142146.41, 141282.84, 144571.34]
latency_get_conf1    =  [0.091, 0.090, 0.091, 0.094, 0.091,
                         0.089, 0.090, 0.092, 0.093, 0.090]

throughput_set_conf2 =  [124564.03, 141462.73, 140291.81, 139431.12, 135906.50,
                         143163.92, 141904.36, 138504.16, 134372.48, 140056.03]
latency_set_conf2 =     [0.107, 0.093, 0.094, 0.095, 0.097,
                         0.092, 0.093, 0.095, 0.098, 0.095]

throughput_get_conf2 =  [145496.88, 144175.31, 145412.25, 143719.45, 143719.45,
                         146799.77, 144529.55, 145306.59, 137362.64, 134934.56]
latency_get_conf2 =     [0.091, 0.091, 0.090, 0.091, 0.091,
                         0.089, 0.091, 0.090, 0.095, 0.098]

throughput_set_conf2b = [131164.73, 142816.34, 140587.66, 142267.75, 140449.44,
                         141884.22, 141864.09, 142429.86, 138217.00, 143595.62]
latency_set_conf2b =    [0.101, 0.093, 0.094, 0.093, 0.094,
                         0.093, 0.093, 0.093, 0.096, 0.092]

throughput_get_conf2b = [145412.25, 146692.09, 142959.27, 139840.58, 146993.97,
                         144112.98, 147907.11, 147536.16, 140984.06, 145391.11]
latency_get_conf2b =    [0.090, 0.090, 0.092, 0.094, 0.090,
                         0.091, 0.089, 0.089, 0.093, 0.090]

throughput_set_conf3a = [139062.72, 135593.22, 126422.25, 120787.53, 123670.53,
                         127502.23, 125344.70, 122865.22, 140805.41, 141003.95]
latency_set_conf3a =    [0.096, 0.098, 0.105, 0.111, 0.108,
                         0.105, 0.107, 0.110, 0.094, 0.094]

throughput_get_conf3a = [139217.59, 131095.97, 137249.53, 123426.31, 121966.09,
                         119075.98, 133226.75, 144279.31, 145222.19, 145201.11]
latency_get_conf3a =    [0.095, 0.100, 0.096, 0.108, 0.108,
                         0.112, 0.099, 0.092, 0.091, 0.091]

throughput_set_conf3b = [139977.61, 142531.36, 128485.16, 120831.32, 137343.77,
                         142166.62, 142146.41, 142348.75, 135299.69, 141522.78]
latency_set_conf3b =    [0.096, 0.094, 0.103, 0.113, 0.098,
                         0.094, 0.094, 0.094, 0.099, 0.095]

throughput_get_conf3b = [140488.91, 147557.92, 121728.55, 135795.77, 145964.09,
                         147514.39, 146541.62, 146434.33, 142734.80, 143472.03]
latency_get_conf3b =    [0.095, 0.090, 0.109, 0.098, 0.091,
                         0.090, 0.091, 0.091, 0.093, 0.093]

throughput_set_conf3b2 = [124192.75, 144029.97, 139528.39, 144717.80, 136314.06,
                          142979.70, 142490.73, 144320.97, 137741.05, 143740.12]
latency_set_conf3b2 =    [0.108, 0.093, 0.095, 0.093, 0.098,
                          0.093, 0.094, 0.093, 0.097, 0.093]

throughput_get_conf3b2 = [140944.33, 146649.08, 147123.73, 138523.34, 135483.00,
                          145666.42, 145560.41, 145730.11, 142959.27, 144258.52]
latency_get_conf3b2 =    [0.094, 0.091, 0.090, 0.095, 0.098,
                          0.091, 0.091, 0.091, 0.093, 0.092]

throughput_set_conf3c = [137665.20, 142005.11, 140134.53, 143740.12, 135135.14,
                         143678.16, 144550.44, 142126.22, 140964.20, 142714.42]
latency_set_conf3c =    [0.098, 0.095, 0.096, 0.094, 0.100,
                         0.094, 0.094, 0.095, 0.096, 0.094]

throughput_get_conf3c = [145074.70, 147318.80, 147907.11, 148323.94, 147710.48,
                         146477.22, 146070.69, 149566.27, 138446.62, 147623.27]
latency_get_conf3c =    [0.092, 0.091, 0.090, 0.090, 0.091,
                         0.091, 0.092, 0.090, 0.096, 0.091]

throughput_set_conf3d = [139938.42, 143225.44, 143184.42, 140213.12, 142918.39,
                         144133.75, 141562.84, 141063.61, 139958.02, 144009.22]
latency_set_conf3d =    [0.097, 0.094, 0.094, 0.097, 0.095,
                         0.094, 0.096, 0.096, 0.097, 0.094]

throughput_get_conf3d = [147972.78, 145180.02, 146606.06, 141864.09, 147449.12,
                         145815.11, 146563.09, 140469.17, 146177.45, 147492.62]
latency_get_conf3d =    [0.091, 0.092, 0.092, 0.094, 0.091,
                         0.092, 0.092, 0.095, 0.092, 0.091]

throughput_set_conf3e = [137722.08, 143843.50, 133280.03, 140528.39, 135098.62,
                         136630.69, 143616.27, 144487.80, 138350.86, 143843.50]
latency_set_conf3e =    [0.099, 0.095, 0.102, 0.097, 0.101,
                         0.100, 0.095, 0.094, 0.099, 0.095]

throughput_get_conf3e = [143988.48, 131527.03, 126087.50, 117109.73, 127795.53,
                         148104.27, 148038.48, 145391.11, 145201.11, 143760.78]
latency_get_conf3e =    [0.094, 0.103, 0.107, 0.117, 0.107,
                         0.091, 0.091, 0.093, 0.093, 0.094]



# -----------------------
# Plot 1: Throughput Comparison
# -----------------------
plt.figure(figsize=(10, 6))
plt.plot(iterations, throughput_set_conf1, "d-", label="Config1")
plt.plot(iterations, throughput_set_conf2, "v-", label="Config2")
plt.plot(iterations, throughput_set_conf2b, "h-", label="Config2b")
plt.plot(iterations, throughput_set_conf3a, "o-", label="Config3a")
plt.plot(iterations, throughput_set_conf3b, "v-", label="Config3b")
plt.plot(iterations, throughput_set_conf3b2, "v--", label="Config3b2")
plt.plot(iterations, throughput_set_conf3c, "s-", label="Config3c")
plt.plot(iterations, throughput_set_conf3d, "p-", label="Config3d")
plt.plot(iterations, throughput_set_conf3e, "o-", label="Config3e")
plt.xlabel("Run")
plt.ylabel("SET Throughput (requests/sec)")
plt.title("SET Benchmark Throughput Comparison")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# -----------------------
# Plot 2: Latency Comparison
# -----------------------
plt.figure(figsize=(10, 6))
plt.plot(iterations, throughput_get_conf1, "d-", label="Config1")
plt.plot(iterations, throughput_get_conf2, "v-", label="Config2")
plt.plot(iterations, throughput_get_conf2b, "h-", label="Config2b")
plt.plot(iterations, throughput_get_conf3a, "o-", label="Config3a")
plt.plot(iterations, throughput_get_conf3b, "v-", label="Config3b")
plt.plot(iterations, throughput_get_conf3b2, "v--", label="Config3b2")
plt.plot(iterations, throughput_get_conf3c, "s-", label="Config3c")
plt.plot(iterations, throughput_get_conf3d, "p-", label="Config3d")
plt.plot(iterations, throughput_get_conf3e, "o-", label="Config3e")
plt.xlabel("Run")
plt.ylabel("GET Throughput (requests/sec)")
plt.title("GET Benchmark Throughput Comparison")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# -----------------------
# Plot 1: Throughput Comparison
# -----------------------
plt.figure(figsize=(10, 6))
plt.plot(iterations, latency_set_conf1, "d-", label="Config1")
plt.plot(iterations, latency_set_conf2, "v-", label="Config2")
plt.plot(iterations, latency_set_conf2b, "h-", label="Config2b")
plt.plot(iterations, latency_set_conf3a, "o-", label="Config3a")
plt.plot(iterations, latency_set_conf3b, "v-", label="Config3b")
plt.plot(iterations, latency_set_conf3b2, "v--", label="Config3b2")
plt.plot(iterations, latency_set_conf3c, "s-", label="Config3c")
plt.plot(iterations, latency_set_conf3d, "p-", label="Config3d")
plt.plot(iterations, latency_set_conf3e, "o-", label="Config3e")
plt.xlabel("Run")
plt.ylabel("SET Latency (requests/sec)")
plt.title("SET Benchmark Latency Comparison")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# -----------------------
# Plot 2: Latency Comparison
# -----------------------
plt.figure(figsize=(10, 6))
plt.plot(iterations, latency_get_conf1, "d-", label="Config1")
plt.plot(iterations, latency_get_conf2, "v-", label="Config2")
plt.plot(iterations, latency_get_conf2b, "h-", label="Config2b")
plt.plot(iterations, latency_get_conf3a, "o-", label="Config3a")
plt.plot(iterations, latency_get_conf3b, "v-", label="Config3b")
plt.plot(iterations, latency_get_conf3b2, "v--", label="Config3b2")
plt.plot(iterations, latency_get_conf3c, "s-", label="Config3c")
plt.plot(iterations, latency_get_conf3d, "p-", label="Config3d")
plt.plot(iterations, latency_set_conf3e, "o-", label="Config3e")
plt.xlabel("Run")
plt.ylabel("GET Latency (requests/sec)")
plt.title("GET Benchmark Latency Comparison")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Iteration numbers (assumed 10 runs)
iterations = list(range(1, 11))

throughput_set_conf1 =  [135226.50, 139918.84, 140765.77, 140429.72, 134952.77,
                         143802.12, 144341.80, 145815.11, 135888.03, 139860.14]
latency_set_conf1    =  [0.098, 0.094, 0.094, 0.094, 0.098,
                         0.092, 0.092, 0.091, 0.097, 0.094]

throughput_get_conf1 =  [143905.59, 145645.20, 144341.80, 139489.47, 145496.88,
                         148698.89, 145475.70, 142146.41, 141282.84, 144571.34]
latency_get_conf1    =  [0.091, 0.090, 0.091, 0.094, 0.091,
                         0.089, 0.090, 0.092, 0.093, 0.090]

throughput_set_conf2 =  [124564.03, 141462.73, 140291.81, 139431.12, 135906.50,
                         143163.92, 141904.36, 138504.16, 134372.48, 140056.03]
latency_set_conf2 =     [0.107, 0.093, 0.094, 0.095, 0.097,
                         0.092, 0.093, 0.095, 0.098, 0.095]

throughput_get_conf2 =  [145496.88, 144175.31, 145412.25, 143719.45, 143719.45,
                         146799.77, 144529.55, 145306.59, 137362.64, 134934.56]
latency_get_conf2 =     [0.091, 0.091, 0.090, 0.091, 0.091,
                         0.089, 0.091, 0.090, 0.095, 0.098]

throughput_set_conf2b = [131164.73, 142816.34, 140587.66, 142267.75, 140449.44,
                         141884.22, 141864.09, 142429.86, 138217.00, 143595.62]
latency_set_conf2b =    [0.101, 0.093, 0.094, 0.093, 0.094,
                         0.093, 0.093, 0.093, 0.096, 0.092]

throughput_get_conf2b = [145412.25, 146692.09, 142959.27, 139840.58, 146993.97,
                         144112.98, 147907.11, 147536.16, 140984.06, 145391.11]
latency_get_conf2b =    [0.090, 0.090, 0.092, 0.094, 0.090,
                         0.091, 0.089, 0.089, 0.093, 0.090]

throughput_set_conf3a = [139062.72, 135593.22, 126422.25, 120787.53, 123670.53,
                         127502.23, 125344.70, 122865.22, 140805.41, 141003.95]
latency_set_conf3a =    [0.096, 0.098, 0.105, 0.111, 0.108,
                         0.105, 0.107, 0.110, 0.094, 0.094]

throughput_get_conf3a = [139217.59, 131095.97, 137249.53, 123426.31, 121966.09,
                         119075.98, 133226.75, 144279.31, 145222.19, 145201.11]
latency_get_conf3a =    [0.095, 0.100, 0.096, 0.108, 0.108,
                         0.112, 0.099, 0.092, 0.091, 0.091]

throughput_set_conf3b = [139977.61, 142531.36, 128485.16, 120831.32, 137343.77,
                         142166.62, 142146.41, 142348.75, 135299.69, 141522.78]
latency_set_conf3b =    [0.096, 0.094, 0.103, 0.113, 0.098,
                         0.094, 0.094, 0.094, 0.099, 0.095]

throughput_get_conf3b = [140488.91, 147557.92, 121728.55, 135795.77, 145964.09,
                         147514.39, 146541.62, 146434.33, 142734.80, 143472.03]
latency_get_conf3b =    [0.095, 0.090, 0.109, 0.098, 0.091,
                         0.090, 0.091, 0.091, 0.093, 0.093]

throughput_set_conf3b2 = [124192.75, 144029.97, 139528.39, 144717.80, 136314.06,
                          142979.70, 142490.73, 144320.97, 137741.05, 143740.12]
latency_set_conf3b2 =    [0.108, 0.093, 0.095, 0.093, 0.098,
                          0.093, 0.094, 0.093, 0.097, 0.093]

throughput_get_conf3b2 = [140944.33, 146649.08, 147123.73, 138523.34, 135483.00,
                          145666.42, 145560.41, 145730.11, 142959.27, 144258.52]
latency_get_conf3b2 =    [0.094, 0.091, 0.090, 0.095, 0.098,
                          0.091, 0.091, 0.091, 0.093, 0.092]

throughput_set_conf3c = [137665.20, 142005.11, 140134.53, 143740.12, 135135.14,
                         143678.16, 144550.44, 142126.22, 140964.20, 142714.42]
latency_set_conf3c =    [0.098, 0.095, 0.096, 0.094, 0.100,
                         0.094, 0.094, 0.095, 0.096, 0.094]

throughput_get_conf3c = [145074.70, 147318.80, 147907.11, 148323.94, 147710.48,
                         146477.22, 146070.69, 149566.27, 138446.62, 147623.27]
latency_get_conf3c =    [0.092, 0.091, 0.090, 0.090, 0.091,
                         0.091, 0.092, 0.090, 0.096, 0.091]

throughput_set_conf3d = [139938.42, 143225.44, 143184.42, 140213.12, 142918.39,
                         144133.75, 141562.84, 141063.61, 139958.02, 144009.22]
latency_set_conf3d =    [0.097, 0.094, 0.094, 0.097, 0.095,
                         0.094, 0.096, 0.096, 0.097, 0.094]

throughput_get_conf3d = [147972.78, 145180.02, 146606.06, 141864.09, 147449.12,
                         145815.11, 146563.09, 140469.17, 146177.45, 147492.62]
latency_get_conf3d =    [0.091, 0.092, 0.092, 0.094, 0.091,
                         0.092, 0.092, 0.095, 0.092, 0.091]

throughput_set_conf3e = [137722.08, 143843.50, 133280.03, 140528.39, 135098.62,
                         136630.69, 143616.27, 144487.80, 138350.86, 143843.50]
latency_set_conf3e =    [0.099, 0.095, 0.102, 0.097, 0.101,
                         0.100, 0.095, 0.094, 0.099, 0.095]

throughput_get_conf3e = [143988.48, 131527.03, 126087.50, 117109.73, 127795.53,
                         148104.27, 148038.48, 145391.11, 145201.11, 143760.78]
latency_get_conf3e =    [0.094, 0.103, 0.107, 0.117, 0.107,
                         0.091, 0.091, 0.093, 0.093, 0.094]

config_names = ['Config1', 'Config2', 'Config2b', 'Config3a', 'Config3b', 'Config3b2', 'Config3c', 'Config3d', 'Config3e']

# Compute average metrics for each config
def avg_metrics(throughput_set, latency_set, throughput_get, latency_get):
    return (np.mean(throughput_set), np.mean(latency_set),
            np.mean(throughput_get), np.mean(latency_get))

avg_conf1 = avg_metrics(throughput_set_conf1, latency_set_conf1, throughput_get_conf1, latency_get_conf1)
avg_conf2 = avg_metrics(throughput_set_conf2, latency_set_conf2, throughput_get_conf2, latency_get_conf2)
avg_conf2b = avg_metrics(throughput_set_conf2b, latency_set_conf2b, throughput_get_conf2b, latency_get_conf2b)
avg_conf3a = avg_metrics(throughput_set_conf3a, latency_set_conf3a, throughput_get_conf3a, latency_get_conf3a)
avg_conf3b = avg_metrics(throughput_set_conf3b, latency_set_conf3b, throughput_get_conf3b, latency_get_conf3b)
avg_conf3b2 = avg_metrics(throughput_set_conf3b2, latency_set_conf3b2, throughput_get_conf3b2, latency_get_conf3b2)
avg_conf3c = avg_metrics(throughput_set_conf3c, latency_set_conf3c, throughput_get_conf3c, latency_get_conf3c)
avg_conf3d = avg_metrics(throughput_set_conf3d, latency_set_conf3d, throughput_get_conf3d, latency_get_conf3d)
avg_conf3e = avg_metrics(throughput_set_conf3e, latency_set_conf3e, throughput_get_conf3e, latency_get_conf3e)
# Organize the average metrics for all configurations
# Each average metric is a tuple:
# (avg_set_throughput, avg_set_latency, avg_get_throughput, avg_get_latency)
avg_all = [avg_conf1, avg_conf2, avg_conf2b, avg_conf3a, avg_conf3b, avg_conf3b2, avg_conf3c, avg_conf3d, avg_conf3e]

# Separate each metric into lists per config (preserving config order)
avg_set_throughput = [x[0] for x in avg_all]
avg_set_latency    = [x[1] for x in avg_all]
avg_get_throughput = [x[2] for x in avg_all]
avg_get_latency    = [x[3] for x in avg_all]

# Since throughput (req/sec) and latency (ms) have different scales, 
# we plot them on dual y-axes as grouped bars.
x = np.arange(len(config_names))
width = 0.2  # width of each bar

fig, ax1 = plt.subplots(figsize=(12, 7))
ax2 = ax1.twinx()

# Plot SET and GET throughput on ax1
bars1 = ax1.bar(x - width, avg_set_throughput, width, label="SET Throughput (req/sec)", color="skyblue")
bars2 = ax1.bar(x, avg_get_throughput, width, label="GET Throughput (req/sec)", color="lightgreen")

# Plot SET and GET latency on ax2
bars3 = ax2.bar(x + width, avg_set_latency, width, label="SET Latency (ms)", color="salmon")
bars4 = ax2.bar(x + 2*width, avg_get_latency, width, label="GET Latency (ms)", color="plum")

# Set x-axis labels and title
ax1.set_xticks(x + 0.5*width)
ax1.set_xticklabels(config_names)
ax1.set_xlabel("Configuration")
ax1.set_ylabel("Throughput (requests/sec)")
ax2.set_ylabel("Latency (ms)")
plt.title("Average SET/GET Throughput and Latency per Configuration")

# Create a single legend
bars = bars1 + bars2 + bars3 + bars4
labels = [bar.get_label() for bar in bars]
ax1.legend(bars, labels, loc="upper left")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/21/m8yyn3tn65gfs63ky7jxkw6r0000gn/T/ipykernel_70579/3514903544.py:151: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   ax1.legend(bars, labels, loc="upper left")
